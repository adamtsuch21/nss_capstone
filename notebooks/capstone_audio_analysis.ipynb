# %%
import pandas as pd
import ast
import csv

# %%
file = open("another_one_bites_the_dust_audio_analysis.txt", 'r')
contents = file.read()
dictionary = ast.literal_eval(contents)
file.close()
bites_dust_seg = dictionary['segments']

# %%
headings = ['start', 'duration', 'confidence', 'loudness_start', 'loudness_max_time', 'loudness_max', 'loudness_end', 'pitches', 'timbre']

# %%
def create_song_csv(csv_name, headings_list, data_list):
    "creates a csv file from a list spotify data"
    with open(csv_name, 'w') as out_file:
        writer = csv.DictWriter(out_file, headings_list)
        writer.writeheader()
        for row in data_list:
            if row:
                writer.writerow(row)
        return;

# %%
create_song_csv('bites_the_dust_seg.csv', headings, bites_dust_seg)

# %%
bites_the_dust_seg = pd.read_csv('bites_the_dust_seg.csv')
bites_the_dust_seg
# Out:
#          start  duration  confidence  loudness_start  loudness_max_time  \
# 0      0.00000   0.29610       0.000         -60.000            0.24596
# 1      0.29610   0.13546       1.000         -53.476            0.02531
# 2      0.43156   0.13234       0.530         -43.267            0.02876
# 3      0.56390   0.27424       1.000         -39.457            0.01232
# 4      0.83814   0.22322       0.699         -45.709            0.01215
# ..         ...       ...         ...             ...                ...
# 836  209.56590   0.10222       0.780         -20.694            0.01025
# 837  209.66812   0.58503       0.713         -17.295            0.03351
# 838  210.25314   1.49683       0.847         -22.942            0.05653
# 839  211.74998   0.60671       0.007         -42.829            0.07469
# 840  212.35669   3.50998       0.204         -48.496            0.02281
#
#      loudness_max  loudness_end  \
# 0         -53.030           0.0
# 1         -36.512           0.0
# ...

# %%
file = open('another_one_bites_the_dust_remaster_audio_analysis.txt', 'r')
contents = file.read()
dictionary = ast.literal_eval(contents)
file.close()
bites_dust_rem_seg = dictionary['segments']

# %%
create_song_csv('bites_the_dust_rem_seg.csv', headings, bites_dust_rem_seg)

# %%
bites_the_dust_rem_seg = pd.read_csv('bites_the_dust_rem_seg.csv')
bites_the_dust_rem_seg
# Out:
#          start  duration  confidence  loudness_start  loudness_max_time  \
# 0      0.00000   0.39583       1.000         -60.000            0.27953
# 1      0.39583   0.12023       0.589         -37.984            0.01888
# 2      0.51605   0.27937       1.000         -35.540            0.01863
# 3      0.79542   0.21478       0.756         -40.844            0.01550
# 4      1.01020   0.32063       1.000         -50.552            0.06801
# ..         ...       ...         ...             ...                ...
# 829  209.74231   0.32571       0.061         -11.662            0.04018
# 830  210.06802   1.48871       0.789         -15.404            0.05249
# 831  211.55673   0.22050       0.107         -35.710            0.07741
# 832  211.77724   0.38376       0.013         -38.053            0.02515
# 833  212.16100   2.49234       0.245         -41.872            0.00807
#
#      loudness_max  loudness_end  \
# 0         -31.530           0.0
# 1         -30.624           0.0
# ...
